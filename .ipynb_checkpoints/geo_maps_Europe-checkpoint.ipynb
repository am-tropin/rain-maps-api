# %%
import pandas as pd
import numpy as np
import time

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm

import geopandas as gpd
import geopy.distance

import glob
import os

# %%
# https://ec.europa.eu/eurostat/web/gisco/geodata/reference-data/administrative-units-statistical-units/countries

# %%
# eu_url = "https://gisco-services.ec.europa.eu/distribution/v2/countries/download/ref-countries-2020-01m.geojson.zip"
eu_url = "https://gisco-services.ec.europa.eu/distribution/v2/countries/download/ref-countries-2020-10m.geojson.zip"

# %%
# geoJSON

import opendatasets as od

od.download(eu_url)
# Out:
# Downloading https://gisco-services.ec.europa.eu/distribution/v2/countries/download/ref-countries-2020-10m.geojson.zip to ./ref-countries-2020-10m.geojson.zip
# 10567680it [00:05, 1906213.21it/s]

# %%
geo_dir = 'eu_geo_maps'

# os.mkdir(geo_dir)

# %%
import zipfile

with zipfile.ZipFile("ref-countries-2020-10m.geojson.zip", 'r') as zip_ref:
# with zipfile.ZipFile("ref-countries-2020-01m.geojson.zip", 'r') as zip_ref:
    zip_ref.extractall(geo_dir)

# %%
geo_regions_eu = gpd.read_file(geo_dir + '/' + 'CNTR_RG_10M_2020_4326.geojson')
# geo_eu = gpd.read_file(geo_dir + '/' + 'CNTR_BN_01M_2020_4326.geojson')
# geo_coastl_eu = gpd.read_file(geo_dir + '/' + 'CNTR_BN_60M_2020_4326_COASTL.geojson')
# geo_inland_eu = gpd.read_file(geo_dir + '/' + 'CNTR_BN_60M_2020_4326_INLAND.geojson')

geo_boundaries_eu = gpd.read_file(geo_dir + '/' + 'CNTR_BN_10M_2020_4326.geojson')
# geo_labels_eu = gpd.read_file(geo_dir + '/' + 'CNTR_LB_2020_4326.geojson')

# %%
print(geo_regions_eu.shape)
print(geo_regions_eu.crs)
# Out:
# (257, 14)
# epsg:4326

# %%
geo_eu.columns
# Out:
# Index(['id', 'CNTR_ID', 'CNTR_NAME', 'NAME_ENGL', 'NAME_FREN', 'ISO3_CODE',
#        'SVRG_UN', 'CAPT', 'EU_STAT', 'EFTA_STAT', 'CC_STAT', 'NAME_GERM',
#        'FID', 'geometry'],
#       dtype='object')

# %%
geo_eu.head()
# Out:
#    id CNTR_ID          CNTR_NAME      NAME_ENGL    NAME_FREN ISO3_CODE  \
# 0  AQ      AQ         Antarctica     Antarctica  Antarctique       ATA
# 1  BV      BV          Bouvetøya  Bouvet Island   Île Bouvet       BVT
# 2  BW      BW  Botswana-Botswana       Botswana     Botswana       BWA
# 3  BY      BY           Беларусь        Belarus  Biélorussie       BLR
# 4  BZ      BZ             Belize         Belize       Belize       BLZ
#
#                  SVRG_UN      CAPT EU_STAT EFTA_STAT CC_STAT    NAME_GERM FID  \
# 0  Sovereignty unsettled      None       F         F       F    Antarktis  AQ
# 1           NO Territory      None       F         F       F  Bouvetinsel  BV
# 2        UN Member State  Gaborone       F         F       F     Botsuana  BW
# 3        UN Member State     Minsk       F         F       F      Belarus  BY
# 4        UN Member State  Belmopan       F         F       F       Belize  BZ
#
#                                             geometry
# 0  MULTIPOLYGON (((-57.47360 -63.56230, -57.63190...
# 1  POLYGON ((3.08710 -54.40140, 3.40700 -54.34860...
# 2  POLYGON ((25.27030 -17.79890, 26.18730 -19.502...
# 3  POLYGON ((31.78690 52.11150, 30.91120 52.02520...
# 4  MULTIPOLYGON (((-87.68040 17.35980, -87.85440 ...

# %%
# geo_eu = geo_eu.rename(columns={'name':'district'}).drop(['cartodb_id'], axis=1)
# geo_eu.head()

# %%
geo_eu.plot(column='geometry', cmap='Set3', legend=True)
plt.title('European Countries')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File /opt/homebrew/opt/ipython/libexec/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2334 try:
#    2335     # _get_renderer may change the figure dpi (as vector formats
#    2336     # force the figure dpi to 72), so we need to set it again here.
#    2337     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338         result = print_method(
#    2339             filename,
#    2340             facecolor=facecolor,
#    2341             edgecolor=edgecolor,
#    2342             orientation=orientation,
#    2343             bbox_inches_restore=_bbox_inches_restore,
#    2344             **kwargs)
#    2345 finally:
#    2346     if bbox_inches and restore_bbox:
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2200     optional_kws = {  # Passed by print_figure for other renderers.
#    2201         "dpi", "facecolor", "edgecolor", "orientation",
#    2202         "bbox_inches_restore"}
#    2203     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206 else:  # Let third-parties do as they see fit.
#    2207     print_method = meth
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:410, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     400     deprecation_addendum = (
#     401         f"If any parameter follows {name!r}, they should be passed as "
#     402         f"keyword, not positionally.")
#     403     warn_deprecated(
#     404         since,
#     405         name=repr(name),
#    (...)
#     408                  else deprecation_addendum,
#     409         **kwargs)
# --> 410 return func(*inner_args, **inner_kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:517, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     468 @_api.delete_parameter("3.5", "args")
#     469 def print_png(self, filename_or_obj, *args,
#     470               metadata=None, pil_kwargs=None):
#     471     """
#     472     Write the figure to a PNG file.
#     473
#    (...)
#     515         *metadata*, including the default 'Software' key.
#     516     """
# --> 517     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:463, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     458 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     459     """
#     460     Draw the canvas, then save it using `.image.imsave` (to which
#     461     *pil_kwargs* and *metadata* are forwarded).
#     462     """
# --> 463     FigureCanvasAgg.draw(self)
#     464     mpl.image.imsave(
#     465         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     466         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:399, in FigureCanvasAgg.draw(self)
#     397 def draw(self):
#     398     # docstring inherited
# --> 399     self.renderer = self.get_renderer()
#     400     self.renderer.clear()
#     401     # Acquire a lock on the shared font cache.
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:384, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     379 @functools.wraps(func)
#     380 def wrapper(*inner_args, **inner_kwargs):
#     381     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     382         # Early return in the simple, non-deprecated case (much faster than
#     383         # calling bind()).
# --> 384         return func(*inner_args, **inner_kwargs)
#     385     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     386     if is_varargs and arguments.get(name):
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:416, in FigureCanvasAgg.get_renderer(self, cleared)
#     414 reuse_renderer = (self._lastKey == key)
#     415 if not reuse_renderer:
# --> 416     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     417     self._lastKey = key
#     418 elif cleared:
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:84, in RendererAgg.__init__(self, width, height, dpi)
#      82 self.width = width
#      83 self.height = height
# ---> 84 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      85 self._filter_renderers = []
#      87 self._update_methods()
#
# ValueError: Image size of 155824x5436 pixels is too large. It must be less than 2^16 in each direction.

# %%
germany_gpd = geo_eu[geo_eu['FID'] == 'DE']

germany_gpd.plot(column='geometry', cmap='Set3') # , cmap='Set3', legend=True
geo_labels_eu.plot(column='geometry', cmap='black')
plt.title('Germany')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 4
#       1 germany_gpd = geo_eu[geo_eu['FID'] == 'DE']
#       3 germany_gpd.plot(column='geometry', cmap='Set3') # , cmap='Set3', legend=True
# ----> 4 geo_labels_eu.plot(column='geometry', cmap='black')
#       5 plt.title('Germany')
#       6 plt.show()
#
# File /opt/homebrew/lib/python3.11/site-packages/geopandas/plotting.py:968, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     966 kind = kwargs.pop("kind", "geo")
#     967 if kind == "geo":
# --> 968     return plot_dataframe(data, *args, **kwargs)
#     969 if kind in self._pandas_kinds:
#     970     # Access pandas plots
#     971     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/geopandas/plotting.py:869, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     867         markersize = np.take(markersize, multiindex, axis=0)
#     868         markersize = markersize[point_idx & np.invert(nan_idx)]
# --> 869     _plot_point_collection(
#     870         ax,
#     871         points,
#     872         subset,
#     873         vmin=mn,
#     874         vmax=mx,
#     875         markersize=markersize,
#     876         cmap=cmap,
#     877         **style_kwds,
#     878     )
#     880 missing_data = not expl_series[nan_idx].empty
#     881 if missing_kwds is not None and missing_data:
#
# File /opt/homebrew/lib/python3.11/site-packages/geopandas/plotting.py:306, in _plot_point_collection(ax, geoms, values, color, cmap, vmin, vmax, marker, markersize, **kwargs)
#     303 _expand_kwargs(kwargs, multiindex)
#     305 if "norm" not in kwargs:
# --> 306     collection = ax.scatter(x, y, vmin=vmin, vmax=vmax, cmap=cmap, **kwargs)
#     307 else:
#     308     collection = ax.scatter(x, y, cmap=cmap, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4621, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4619 if colors is None:
#    4620     collection.set_array(c)
# -> 4621     collection.set_cmap(cmap)
#    4622     collection.set_norm(norm)
#    4623     collection._scale_norm(norm, vmin, vmax)
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/cm.py:603, in ScalarMappable.set_cmap(self, cmap)
#     594 """
#     595 Set the colormap for luminance data.
#     596
#    (...)
#     599 cmap : `.Colormap` or str or None
#     600 """
#     601 in_init = self.cmap is None
# --> 603 self.cmap = _ensure_cmap(cmap)
#     604 if not in_init:
#     605     self.changed()
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/cm.py:741, in _ensure_cmap(cmap)
#     738 cmap_name = cmap if cmap is not None else mpl.rcParams["image.cmap"]
#     739 # use check_in_list to ensure type stability of the exception raised by
#     740 # the internal usage of this (ValueError vs KeyError)
# --> 741 _api.check_in_list(sorted(_colormaps), cmap=cmap_name)
#     742 return mpl.colormaps[cmap_name]
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/_api/__init__.py:131, in check_in_list(_values, _print_supported_values, **kwargs)
#     129 if _print_supported_values:
#     130     msg += f"; supported values are {', '.join(map(repr, values))}"
# --> 131 raise ValueError(msg)
#
# ValueError: 'black' is not a valid value for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots(1, figsize=(6, 6))
# Base layer with all the areas for the background
for poly in germany_gpd['geometry']:
    gpd.plotting.plot_multipolygon(ax, poly, facecolor='lightgrey', linewidth=0.025)
# Smallest areas
for poly in geo_labels_eu['geometry']:
    gpd.plotting.plot_multipolygon(ax, poly, alpha=1, facecolor='red', linewidth=0)
ax.set_axis_off()
f.suptitle('AAAAA')
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 4
#       2 # Base layer with all the areas for the background
#       3 for poly in germany_gpd['geometry']:
# ----> 4     gpd.plotting.plot_multipolygon(ax, poly, facecolor='lightgrey', linewidth=0.025)
#       5 # Smallest areas
#       6 for poly in geo_labels_eu['geometry']:
#
# AttributeError: module 'geopandas.plotting' has no attribute 'plot_multipolygon'

# %%
geo_coastl_eu.head()
# Out:
#   EU_FLAG EFTA_FLAG CC_FLAG COAS_FLAG  CNTR_BN_ID OTHR_FLAG  POL_STAT  \
# 0       F         F       F         T         157         T         0
# 1       F         F       F         T         158         T         0
# 2       F         F       F         T         159         T         0
# 3       F         F       F         T         160         T         0
# 4       F         F       F         T         161         T         0
#
#    CNTR_BN_CODE CNTR_CODE  FID  \
# 0           157        AQ  157
# 1           158        AQ  158
# 2           159        AQ  159
# 3           160        AQ  160
# 4           161        AQ  161
#
#                                             geometry
# 0  LINESTRING (-58.73750 -62.06850, -58.38930 -61...
# 1  LINESTRING (-180.00000 -89.90000, -180.00000 -...
# 2  LINESTRING (-55.38080 -61.15310, -55.33190 -60...
# 3  LINESTRING (-45.78690 -60.56430, -45.68330 -60...
# 4  LINESTRING (-45.59800 -60.58720, -45.53420 -60...

# %%
geo_inland_eu.head()
# Out:
#   EU_FLAG EFTA_FLAG CC_FLAG COAS_FLAG  CNTR_BN_ID OTHR_FLAG  POL_STAT  \
# 0       F         F       F         F         171         T         0
# 1       F         F       F         F         203         T         0
# 2       F         F       F         F         204         T         0
# 3       F         F       F         F         206         T         0
# 4       F         F       F         F         207         T         0
#
#    CNTR_BN_CODE CNTR_CODE  FID  \
# 0           171        CL  171
# 1           203        UY  203
# 2           204        UY  204
# 3           206        ZA  206
# 4           207        SN  207
#
#                                             geometry
# 0  LINESTRING (-68.60750 -54.89340, -68.60820 -53...
# 1  LINESTRING (-57.61900 -30.17590, -58.13160 -31...
# 2  LINESTRING (-53.37800 -33.75040, -53.50950 -33...
# 3  LINESTRING (27.03270 -29.61710, 27.37000 -29.4...
# 4  LINESTRING (-16.50680 13.59090, -16.13950 13.5...

# %%
germany_coastl_gpd = geo_coastl_eu[geo_coastl_eu['CNTR_CODE'] == 'DE']

germany_coastl_gpd.plot(column='geometry') # , cmap='Set3', legend=True
plt.title('Germany')
plt.show()

# %%
germany_inland_gpd = geo_inland_eu[geo_inland_eu['CNTR_CODE'] == 'DE']

germany_inland_gpd.plot(column='geometry') # , cmap='Set3', legend=True
plt.title('Germany')
plt.show()

# %%
geo_labels_eu.head()
# Out:
#    id CNTR_ID                 CNTR_NAME             NAME_ENGL  \
# 0  AD      AD                   Andorra               Andorra
# 1  AE      AE  الإمارات العربية المتحدة  United Arab Emirates
# 2  AF      AF       افغانستان-افغانستان           Afghanistan
# 3  AG      AG       Antigua and Barbuda   Antigua and Barbuda
# 4  AI      AI                  Anguilla              Anguilla
#
#              NAME_FREN ISO3_CODE                          SVRG_UN  \
# 0              Andorre       AND                  UN Member State
# 1  Émirats arabes unis       ARE                  UN Member State
# 2          Afghanistan       AFG                  UN Member State
# 3   Antigua-et-Barbuda       ATG                  UN Member State
# 4             Anguilla       AIA  UK Non-Self-Governing Territory
#
#                CAPT EU_STAT EFTA_STAT CC_STAT                       NAME_GERM  \
# 0  Andorra la Vella       F         F       F                         Andorra
# 1         Abu Dhabi       F         F       F  Vereinigten Arabischen Emirate
# 2             Kabul       F         F       F                     Afghanistan
# 3         St John's       F         F       F             Antigua und Barbuda
# 4        The Valley       F         F       F                        Anguilla
#
#   FID                    geometry
# 0  AD    POINT (1.59140 42.54220)
# 1  AE   POINT (53.98240 23.46560)
# 2  AF   POINT (65.99790 33.81790)
# 3  AG  POINT (-61.80970 17.07850)
# 4  AI  POINT (-63.03760 18.22410)

# %%
cities = pd.read_csv("worldcities.csv")
cities.head()
# Out:
#         city city_ascii      lat       lng    country iso2 iso3   admin_name  \
# 0      Tokyo      Tokyo  35.6897  139.6922      Japan   JP  JPN        Tōkyō
# 1    Jakarta    Jakarta  -6.1750  106.8275  Indonesia   ID  IDN      Jakarta
# 2      Delhi      Delhi  28.6100   77.2300      India   IN  IND        Delhi
# 3  Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN    Guangdong
# 4     Mumbai     Mumbai  19.0761   72.8775      India   IN  IND  Mahārāshtra
#
#    capital  population          id
# 0  primary  37732000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604
# 3    admin  26940000.0  1156237133
# 4    admin  24973000.0  1356226629

# %%
cities_coord = cities[['city', 'lat', 'lng', 'iso2', 'population']].sort_values('population', ascending=False)
cities_coord.head()
# Out:
#         city      lat       lng iso2  population
# 0      Tokyo  35.6897  139.6922   JP  37732000.0
# 1    Jakarta  -6.1750  106.8275   ID  33756000.0
# 2      Delhi  28.6100   77.2300   IN  32226000.0
# 3  Guangzhou  23.1300  113.2600   CN  26940000.0
# 4     Mumbai  19.0761   72.8775   IN  24973000.0

# %%
cities_coord_gdf = gpd.GeoDataFrame(
    cities_coord, geometry=gpd.points_from_xy(cities_coord.lng, cities_coord.lat), crs="EPSG:4326"
)
cities_coord_gdf.head()
# Out:
#         city      lat       lng iso2  population                    geometry
# 0      Tokyo  35.6897  139.6922   JP  37732000.0  POINT (139.69220 35.68970)
# 1    Jakarta  -6.1750  106.8275   ID  33756000.0  POINT (106.82750 -6.17500)
# 2      Delhi  28.6100   77.2300   IN  32226000.0   POINT (77.23000 28.61000)
# 3  Guangzhou  23.1300  113.2600   CN  26940000.0  POINT (113.26000 23.13000)
# 4     Mumbai  19.0761   72.8775   IN  24973000.0   POINT (72.87750 19.07610)

# %%
germany_cities_gpd = cities_coord_gdf[
    (cities_coord_gdf['iso2'] == 'DE') & 
    (cities_coord_gdf['population'] >= 600000 )
]
germany_cities_gpd.head(40)
# Out:
#             city      lat      lng iso2  population                   geometry
# 159       Berlin  52.5200  13.4050   DE   4473101.0  POINT (13.40500 52.52000)
# 290    Stuttgart  48.7775   9.1800   DE   2787724.0   POINT (9.18000 48.77750)
# 317       Munich  48.1375  11.5750   DE   2606021.0  POINT (11.57500 48.13750)
# 335      Hamburg  53.5500  10.0000   DE   2484800.0  POINT (10.00000 53.55000)
# 700      Cologne  50.9364   6.9528   DE   1083498.0   POINT (6.95280 50.93640)
# 1101   Frankfurt  50.1106   8.6822   DE    764104.0   POINT (8.68220 50.11060)
# 1269  Düsseldorf  51.2333   6.7833   DE    645923.0   POINT (6.78330 51.23330)
# 1329     Leipzig  51.3400  12.3750   DE    615081.0  POINT (12.37500 51.34000)

# %%
import geoplot as gplt

# %%
import geoplot.crs as gcrs

ax = gplt.webmap(germany_gpd) # , projection=gcrs.WebMercator()
gplt.pointplot(germany_cities_gpd, ax=ax, color='red')
gplt.polyplot(geo_boundaries_eu, ax=ax)
# Out:
# <GeoAxesSubplot: >

# %%
import requests

# %%
# Countries 2020 files are listed in:

geo_api_url = "https://gisco-services.ec.europa.eu/distribution/v2/countries/countries-2020-files.json"
geo_response = requests.get(geo_api_url)
geo_response.status_code
# Out:
# 200

# %%
geo_request = geo_response.request
geo_request.headers
# Out:
# {'User-Agent': 'python-requests/2.28.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
geo_response.json()
# Out:
# {'csv': {'CNTR_AT_2020.csv': 'csv/CNTR_AT_2020.csv',
#   'CNTR_RG_BN_01M_2020.csv': 'csv/CNTR_RG_BN_01M_2020.csv',
#   'CNTR_RG_BN_03M_2020.csv': 'csv/CNTR_RG_BN_03M_2020.csv',
#   'CNTR_RG_BN_10M_2020.csv': 'csv/CNTR_RG_BN_10M_2020.csv',
#   'CNTR_RG_BN_20M_2020.csv': 'csv/CNTR_RG_BN_20M_2020.csv',
#   'CNTR_RG_BN_60M_2020.csv': 'csv/CNTR_RG_BN_60M_2020.csv'},
#  'geojson': {'CNTR_BN_01M_2020_3035.geojson': 'geojson/CNTR_BN_01M_2020_3035.geojson',
#   'CNTR_BN_01M_2020_3035_COASTL.geojson': 'geojson/CNTR_BN_01M_2020_3035_COASTL.geojson',
#   'CNTR_BN_01M_2020_3035_INLAND.geojson': 'geojson/CNTR_BN_01M_2020_3035_INLAND.geojson',
#   'CNTR_BN_01M_2020_3857.geojson': 'geojson/CNTR_BN_01M_2020_3857.geojson',
#   'CNTR_BN_01M_2020_3857_COASTL.geojson': 'geojson/CNTR_BN_01M_2020_3857_COASTL.geojson',
#   'CNTR_BN_03M_2020_3857.shp.zip': 'shp/CNTR_BN_03M_2020_3857.shp.zip',
#   'CNTR_BN_03M_2020_3857_COASTL.shp.zip': 'shp/CNTR_BN_03M_2020_3857_COASTL.shp.zip',
#   'CNTR_BN_03M_2020_3857_INLAND.shp.zip': 'shp/CNTR_BN_03M_2020_3857_INLAND.shp.zip',
#   'CNTR_BN_03M_2020_4326.shp.zip': 'shp/CNTR_BN_03M_2020_4326.shp.zip',
#   'CNTR_BN_03M_2020_4326_COASTL.shp.zip': 'shp/CNTR_BN_03M_2020_4326_COASTL.shp.zip',
#   'CNTR_BN_03M_2020_4326_INLAND.shp.zip': 'shp/CNTR_BN_03M_2020_4326_INLAND.shp.zip',
#   'CNTR_BN_10M_2020_3035.shp.zip': 'shp/CNTR_BN_10M_2020_3035.shp.zip',
#   'CNTR_BN_10M_2020_3035_COASTL.shp.zip': 'shp/CNTR_BN_10M_2020_3035_COASTL.shp.zip',
#   'CNTR_BN_10M_2020_3035_INLAND.shp.zip': 'shp/CNTR_BN_10M_2020_3035_INLAND.shp.zip',
#   'CNTR_BN_10M_2020_3857.shp.zip': 'shp/CNTR_BN_10M_2020_3857.shp.zip',
#   'CNTR_BN_10M_2020_3857_COASTL.shp.zip': 'shp/CNTR_BN_10M_2020_3857_COASTL.shp.zip',
#   'CNTR_BN_10M_2020_3857_INLAND.shp.zip': 'shp/CNTR_BN_10M_2020_3857_INLAND.shp.zip',
#   'CNTR_BN_10M_2020_4326.shp.zip': 'shp/CNTR_BN_10M_2020_4326.shp.zip',
#   'CNTR_BN_10M_2020_4326_COASTL.shp.zip': 'shp/CNTR_BN_10M_2020_4326_COASTL.shp.zip',
#   'CNTR_BN_10M_2020_4326_INLAND.shp.zip': 'shp/CNTR_BN_10M_2020_4326_INLAND.shp.zip',
#   'CNTR_BN_20M_2020_3035.shp.zip': 'shp/CNTR_BN_20M_2020_3035.shp.zip',
#   'CNTR_BN_20M_2020_3035_COASTL.shp.zip': 'shp/CNTR_BN_20M_2020_3035_COASTL.shp.zip',
#   'CNTR_BN_20M_2020_3035_INLAND.shp.zip': 'shp/CNTR_BN_20M_2020_3035_INLAND.shp.zip',
#   'CNTR_BN_20M_2020_3857.shp.zip': 'shp/CNTR_BN_20M_2020_3857.shp.zip',
#   'CNTR_BN_20M_2020_3857_COASTL.shp.zip': 'shp/CNTR_BN_20M_2020_3857_COASTL.shp.zip',
#   'CNTR_BN_20M_2020_3857_INLAND.shp.zip': 'shp/CNTR_BN_20M_2020_3857_INLAND.shp.zip',
#   'CNTR_BN_20M_2020_4326.shp.zip': 'shp/CNTR_BN_20M_2020_4326.shp.zip',
#   'CNTR_BN_20M_2020_4326_COASTL.shp.zip': 'shp/CNTR_BN_20M_2020_4326_COASTL.shp.zip',
#   'CNTR_BN_20M_2020_4326_INLAND.shp.zip': 'shp/CNTR_BN_20M_2020_4326_INLAND.shp.zip',
#   'CNTR_BN_60M_2020_3035.shp.zip': 'shp/CNTR_BN_60M_2020_3035.shp.zip',
#   'CNTR_BN_60M_2020_3035_COASTL.shp.zip': 'shp/CNTR_BN_60M_2020_3035_COASTL.shp.zip',
#   'CNTR_BN_60M_2020_3035_INLAND.shp.zip': 'shp/CNTR_BN_60M_2020_3035_INLAND.shp.zip',
#   'CNTR_BN_60M_2020_3857.shp.zip': 'shp/CNTR_BN_60M_2020_3857.shp.zip',
#   'CNTR_BN_60M_2020_3857_COASTL.shp.zip': 'shp/CNTR_BN_60M_2020_3857_COASTL.shp.zip',
#   'CNTR_BN_60M_2020_3857_INLAND.shp.zip': 'shp/CNTR_BN_60M_2020_3857_INLAND.shp.zip',
#   'CNTR_BN_60M_2020_4326.shp.zip': 'shp/CNTR_BN_60M_2020_4326.shp.zip',
#   'CNTR_BN_60M_2020_4326_COASTL.shp.zip': 'shp/CNTR_BN_60M_2020_4326_COASTL.shp.zip',
#   'CNTR_BN_60M_2020_4326_INLAND.shp.zip': 'shp/CNTR_BN_60M_2020_4326_INLAND.shp.zip',
#   'CNTR_LB_2020_3035.shp.zip': 'shp/CNTR_LB_2020_3035.shp.zip',
#   'CNTR_LB_2020_3857.shp.zip': 'shp/CNTR_LB_2020_3857.shp.zip',
#   'CNTR_LB_2020_4326.shp.zip': 'shp/CNTR_LB_2020_4326.shp.zip',
#   'CNTR_RG_01M_2020_3035.shp.zip': 'shp/CNTR_RG_01M_2020_3035.shp.zip',
#   'CNTR_RG_01M_2020_3857.shp.zip': 'shp/CNTR_RG_01M_2020_3857.shp.zip',
#   'CNTR_RG_01M_2020_4326.shp.zip': 'shp/CNTR_RG_01M_2020_4326.shp.zip',
#   'CNTR_RG_03M_2020_3035.shp.zip': 'shp/CNTR_RG_03M_2020_3035.shp.zip',
#   'CNTR_RG_03M_2020_3857.shp.zip': 'shp/CNTR_RG_03M_2020_3857.shp.zip',
#   'CNTR_RG_03M_2020_4326.shp.zip': 'shp/CNTR_RG_03M_2020_4326.shp.zip',
#   'CNTR_RG_10M_2020_3035.shp.zip': 'shp/CNTR_RG_10M_2020_3035.shp.zip',
#   'CNTR_RG_10M_2020_3857.shp.zip': 'shp/CNTR_RG_10M_2020_3857.shp.zip',
#   'CNTR_RG_10M_2020_4326.shp.zip': 'shp/CNTR_RG_10M_2020_4326.shp.zip',
#   'CNTR_RG_20M_2020_3035.shp.zip': 'shp/CNTR_RG_20M_2020_3035.shp.zip',
#   'CNTR_RG_20M_2020_3857.shp.zip': 'shp/CNTR_RG_20M_2020_3857.shp.zip',
#   'CNTR_RG_20M_2020_4326.shp.zip': 'shp/CNTR_RG_20M_2020_4326.shp.zip',
#   'CNTR_RG_60M_2020_3035.shp.zip': 'shp/CNTR_RG_60M_2020_3035.shp.zip',
#   'CNTR_RG_60M_2020_3857.shp.zip': 'shp/CNTR_RG_60M_2020_3857.shp.zip',
#   'CNTR_RG_60M_2020_4326.shp.zip': 'shp/CNTR_RG_60M_2020_4326.shp.zip'},
#   'CNTR_RG_01M_2020_4326.svg.zip': 'svg/CNTR_RG_01M_2020_4326.svg.zip',
#   'CNTR_RG_03M_2020_3035.svg.zip': 'svg/CNTR_RG_03M_2020_3035.svg.zip',
#   'CNTR_RG_03M_2020_3857.svg.zip': 'svg/CNTR_RG_03M_2020_3857.svg.zip',
#   'CNTR_RG_03M_2020_4326.svg.zip': 'svg/CNTR_RG_03M_2020_4326.svg.zip',
#   'CNTR_RG_10M_2020_3035.svg.zip': 'svg/CNTR_RG_10M_2020_3035.svg.zip',
#   'CNTR_RG_10M_2020_3857.svg.zip': 'svg/CNTR_RG_10M_2020_3857.svg.zip',
#   'CNTR_RG_10M_2020_4326.svg.zip': 'svg/CNTR_RG_10M_2020_4326.svg.zip',
#   'CNTR_RG_20M_2020_3035.svg.zip': 'svg/CNTR_RG_20M_2020_3035.svg.zip',
#   'CNTR_RG_20M_2020_3857.svg.zip': 'svg/CNTR_RG_20M_2020_3857.svg.zip',
#   'CNTR_RG_20M_2020_4326.svg.zip': 'svg/CNTR_RG_20M_2020_4326.svg.zip',
#   'CNTR_RG_60M_2020_3035.svg.zip': 'svg/CNTR_RG_60M_2020_3035.svg.zip',
#   'CNTR_RG_60M_2020_3857.svg.zip': 'svg/CNTR_RG_60M_2020_3857.svg.zip',
#   'CNTR_RG_60M_2020_4326.svg.zip': 'svg/CNTR_RG_60M_2020_4326.svg.zip'},
#  'topojson': {'CNTR_BN_01M_2020_3035.json': 'topojson/CNTR_BN_01M_2020_3035.json',
#   'CNTR_BN_01M_2020_3035_COASTL.json': 'topojson/CNTR_BN_01M_2020_3035_COASTL.json',
#   'CNTR_BN_01M_2020_3035_INLAND.json': 'topojson/CNTR_BN_01M_2020_3035_INLAND.json',
#   'CNTR_BN_01M_2020_3857.json': 'topojson/CNTR_BN_01M_2020_3857.json',
#   'CNTR_BN_01M_2020_3857_COASTL.json': 'topojson/CNTR_BN_01M_2020_3857_COASTL.json',
#   'CNTR_BN_01M_2020_3857_INLAND.json': 'topojson/CNTR_BN_01M_2020_3857_INLAND.json',
#   'CNTR_BN_01M_2020_4326.json': 'topojson/CNTR_BN_01M_2020_4326.json',
#   'CNTR_BN_01M_2020_4326_COASTL.json': 'topojson/CNTR_BN_01M_2020_4326_COASTL.json',
#   'CNTR_BN_01M_2020_4326_INLAND.json': 'topojson/CNTR_BN_01M_2020_4326_INLAND.json',
#   'CNTR_BN_03M_2020_3035.json': 'topojson/CNTR_BN_03M_2020_3035.json',
#   'CNTR_BN_03M_2020_3035_COASTL.json': 'topojson/CNTR_BN_03M_2020_3035_COASTL.json',
#   'CNTR_BN_03M_2020_3035_INLAND.json': 'topojson/CNTR_BN_03M_2020_3035_INLAND.json',
#   'CNTR_BN_03M_2020_3857.json': 'topojson/CNTR_BN_03M_2020_3857.json',
#   'CNTR_BN_03M_2020_3857_COASTL.json': 'topojson/CNTR_BN_03M_2020_3857_COASTL.json',
#   'CNTR_BN_03M_2020_3857_INLAND.json': 'topojson/CNTR_BN_03M_2020_3857_INLAND.json',
#   'CNTR_BN_03M_2020_4326.json': 'topojson/CNTR_BN_03M_2020_4326.json',
#   'CNTR_BN_03M_2020_4326_COASTL.json': 'topojson/CNTR_BN_03M_2020_4326_COASTL.json',
#   'CNTR_BN_03M_2020_4326_INLAND.json': 'topojson/CNTR_BN_03M_2020_4326_INLAND.json',
#   'CNTR_BN_10M_2020_3035.json': 'topojson/CNTR_BN_10M_2020_3035.json',
#   'CNTR_BN_10M_2020_3035_COASTL.json': 'topojson/CNTR_BN_10M_2020_3035_COASTL.json',
#   'CNTR_BN_10M_2020_3035_INLAND.json': 'topojson/CNTR_BN_10M_2020_3035_INLAND.json',
#   'CNTR_BN_10M_2020_3857.json': 'topojson/CNTR_BN_10M_2020_3857.json',
#   'CNTR_BN_10M_2020_3857_COASTL.json': 'topojson/CNTR_BN_10M_2020_3857_COASTL.json',
#   'CNTR_BN_10M_2020_3857_INLAND.json': 'topojson/CNTR_BN_10M_2020_3857_INLAND.json',
#   'CNTR_BN_10M_2020_4326.json': 'topojson/CNTR_BN_10M_2020_4326.json',
#   'CNTR_BN_10M_2020_4326_COASTL.json': 'topojson/CNTR_BN_10M_2020_4326_COASTL.json',
#   'CNTR_BN_10M_2020_4326_INLAND.json': 'topojson/CNTR_BN_10M_2020_4326_INLAND.json',
#   'CNTR_BN_20M_2020_3035.json': 'topojson/CNTR_BN_20M_2020_3035.json',
#   'CNTR_BN_20M_2020_3035_COASTL.json': 'topojson/CNTR_BN_20M_2020_3035_COASTL.json',
#   'CNTR_BN_20M_2020_3035_INLAND.json': 'topojson/CNTR_BN_20M_2020_3035_INLAND.json',
#   'CNTR_BN_20M_2020_3857.json': 'topojson/CNTR_BN_20M_2020_3857.json',
#   'CNTR_BN_20M_2020_3857_COASTL.json': 'topojson/CNTR_BN_20M_2020_3857_COASTL.json',
#   'CNTR_BN_20M_2020_3857_INLAND.json': 'topojson/CNTR_BN_20M_2020_3857_INLAND.json',
#   'CNTR_BN_20M_2020_4326.json': 'topojson/CNTR_BN_20M_2020_4326.json',
#   'CNTR_BN_20M_2020_4326_COASTL.json': 'topojson/CNTR_BN_20M_2020_4326_COASTL.json',
#   'CNTR_BN_20M_2020_4326_INLAND.json': 'topojson/CNTR_BN_20M_2020_4326_INLAND.json',
#   'CNTR_BN_60M_2020_3035.json': 'topojson/CNTR_BN_60M_2020_3035.json',
#   'CNTR_BN_60M_2020_3035_COASTL.json': 'topojson/CNTR_BN_60M_2020_3035_COASTL.json',
#   'CNTR_BN_60M_2020_3035_INLAND.json': 'topojson/CNTR_BN_60M_2020_3035_INLAND.json',
#   'CNTR_BN_60M_2020_3857.json': 'topojson/CNTR_BN_60M_2020_3857.json',
#   'CNTR_BN_60M_2020_3857_COASTL.json': 'topojson/CNTR_BN_60M_2020_3857_COASTL.json',
#   'CNTR_BN_60M_2020_3857_INLAND.json': 'topojson/CNTR_BN_60M_2020_3857_INLAND.json',
#   'CNTR_BN_60M_2020_4326.json': 'topojson/CNTR_BN_60M_2020_4326.json',
#   'CNTR_BN_60M_2020_4326_COASTL.json': 'topojson/CNTR_BN_60M_2020_4326_COASTL.json',
#   'CNTR_BN_60M_2020_4326_INLAND.json': 'topojson/CNTR_BN_60M_2020_4326_INLAND.json',
#   'CNTR_LB_2020_3035.json': 'topojson/CNTR_LB_2020_3035.json',
#   'CNTR_LB_2020_3857.json': 'topojson/CNTR_LB_2020_3857.json',
#   'CNTR_LB_2020_4326.json': 'topojson/CNTR_LB_2020_4326.json',
#   'CNTR_RG_01M_2020_3035.json': 'topojson/CNTR_RG_01M_2020_3035.json',
#   'CNTR_RG_01M_2020_3857.json': 'topojson/CNTR_RG_01M_2020_3857.json',
#   'CNTR_RG_01M_2020_4326.json': 'topojson/CNTR_RG_01M_2020_4326.json',
#   'CNTR_RG_03M_2020_3035.json': 'topojson/CNTR_RG_03M_2020_3035.json',
#   'CNTR_RG_03M_2020_3857.json': 'topojson/CNTR_RG_03M_2020_3857.json',
#   'CNTR_RG_03M_2020_4326.json': 'topojson/CNTR_RG_03M_2020_4326.json',
#   'CNTR_RG_10M_2020_3035.json': 'topojson/CNTR_RG_10M_2020_3035.json',
#   'CNTR_RG_10M_2020_3857.json': 'topojson/CNTR_RG_10M_2020_3857.json',
#   'CNTR_RG_10M_2020_4326.json': 'topojson/CNTR_RG_10M_2020_4326.json',
#   'CNTR_RG_20M_2020_3035.json': 'topojson/CNTR_RG_20M_2020_3035.json',
#   'CNTR_RG_20M_2020_3857.json': 'topojson/CNTR_RG_20M_2020_3857.json',
#   'CNTR_RG_20M_2020_4326.json': 'topojson/CNTR_RG_20M_2020_4326.json',
#   'CNTR_RG_60M_2020_3035.json': 'topojson/CNTR_RG_60M_2020_3035.json',
#   'CNTR_RG_60M_2020_3857.json': 'topojson/CNTR_RG_60M_2020_3857.json',
#   'CNTR_RG_60M_2020_4326.json': 'topojson/CNTR_RG_60M_2020_4326.json'}}

# %%
# Examples: NUTS_RG_01M_2016_3035_LEVL_0.geojson, CNTR_BN_01M_2016_3035_INLAND.geojson

# theme: 4-character code of theme (NUTS)

# spatialtype: BN/RG/LB
# BN: boundaries (multilines)
# RG: regions (multipolygons)
# LB: labels (points)
# resolution: 60M/20M/10M/03M/01M; map scale the data is optimized (generalized) for.

# year: the year of NUTS regulation (2016/2013/2010/2006/2003).
# projection: 4-digit EPSG code
# EPSG:4326 (WGS84, coordinates in decimal degrees)
# EPSG:3035 (ETRS 1989 in Lambert Azimutal projection with centre in E52N10, coordinates in meters)
# EPSG:3857 (WGS84 Web Mercator Auxiliary Sphere, coordinates in meters)
# subset: depends on the dataset. Common cases:
# NUTS levels 0,1,2,3. No subset code means all NUTS levels are in the same file.
# LEVL_0: NUTS level 0 (countries)
# LEVL_1: NUTS level 1
# LEVL_2: NUTS level 2
# LEVL_3: NUTS level 3
# Country boundaries: coastline or inland line. No subset code means all country boundaries are in the same file.
# INLAND: inland boundaries
# COASTL: coastlines

# %%
# 4326
